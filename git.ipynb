# %%
from jgh.Interface import Interface
import glob

repo = Interface()

for path in glob.glob('*'):
    repo.evaladd(path)
    repo.commitpush(path)
# Out:
# [git pull] Syncing with origin: git@github.com:szitenberg/JordanFishSkinMicrobiome.git
# /master
# [git pull] Syncing with origin: git@github.com:szitenberg/JordanFishSkinMicrobiome.git
# /master
# [git commit stdout] [master 070d5b8] trimmed_reads
# [git commit stdout]  676 files changed, 7848552 insertions(+)
# [git commit stdout]  create mode 100644 trimmed_reads/AS100_S3_L001_R1_001.fastq
# [git commit stdout]  create mode 100644 trimmed_reads/AS100_S3_L001_R2_001.fastq
# [git commit stdout]  create mode 100644 trimmed_reads/AS102_S50_L001_R1_001.fastq
# [git commit stdout]  create mode 100644 trimmed_reads/AS102_S50_L001_R2_001.fastq
# [git commit stdout]  create mode 100644 trimmed_reads/AS103_S51_L001_R1_001.fastq
# [git commit stdout]  create mode 100644 trimmed_reads/AS103_S51_L001_R2_001.fastq
# [git commit stdout]  create mode 100644 trimmed_reads/AS104_S52_L001_R1_001.fastq
# [git commit stdout]  create mode 100644 trimmed_reads/AS104_S52_L001_R2_001.fastq
# ...

# %%
#!git add --all <path> # to delet from online repo
#!git commit -m "delete old files" 
#!git push

# %%
from jgh.Interface import Interface
import glob

repo = Interface()

repo.evaladd('README.md')
repo.commitpush('README.md')
# Out:
# [git pull] Syncing with origin: git@github.com:szitenberg/JordanFishSkinMicrobiome.git
# /master
# [git pull] Syncing with origin: git@github.com:szitenberg/JordanFishSkinMicrobiome.git
# /master
# [git commit stdout] [master 1a3c115] README.md
# [git commit stdout]  1 file changed, 6 insertions(+), 1 deletion(-)
#
#
# [git push stderr] To github.com:szitenberg/JordanFishSkinMicrobiome.git
# [git push stderr]    62010ef..1a3c115  master -> master
